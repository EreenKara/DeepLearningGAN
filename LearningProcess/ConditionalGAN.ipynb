# %% [markdown]
# ### Aşağıdaki başlıklandırmalardan tut, jupyter notebookta tutmaya, bazı ingilizce notlarda dahil olmak üzere, bütün türkçe notlara kadar her şeyi ben yazdım.

# %% [markdown]
# # 1. Dependencies

# %%
from numpy import zeros
from numpy import ones
from numpy.random import randn
from numpy.random import randint
from keras.datasets.cifar10 import load_data
from keras.optimizers import Adam
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import Reshape
from keras.layers import Flatten
from keras.layers import Conv2D
from keras.layers import Conv2DTranspose
from keras.layers import LeakyReLU
from keras.layers import Dropout
from keras.layers import Embedding
from keras.layers import Concatenate

from matplotlib import pyplot as plt

# %% [markdown]
# # 2. Load Data

# %%
#Load data and plot to get a quick understanding
#CIFAR10 classes are: airplane, automobile, bird, cat, deer, dog, frog, horse, ship, truck

(trainX, trainy), (testX, testy) = load_data()

# plot 25 images
for i in range(25):
	plt.subplot(5, 5, 1 + i)
	plt.axis('off')
	plt.imshow(trainX[i])
plt.show()

# %% [markdown]
# Define generator, discriminator, gan and other helper functions
#
# We will use functional way of defining model as we have multiple inputs;
#
# both images and corresponding labels.

# %% [markdown]
# # 3. Define DISCRIMINATOR

# %%
# define the standalone discriminator model
#Given an input image, the Discriminator outputs the likelihood of the image being real.
#Binary classification - true or false (1 or 0). So using sigmoid activation.

#Unlike regular GAN here we are also providing number of classes as input. 
#Input to the model will be both images and labels. 
def define_discriminator(in_shape=(32,32,3), n_classes=10):
	
    # label input
	in_label = Input(shape=(1,))  #Shape 1
	# embedding for categorical input
    #each label (total 10 classes for cifar), will be represented by a vector of size 50. 
    #This vector of size 50 will be learnt by the discriminator
    
    # Embedding layer su ise yarıyormus ilk parametre olarak unique farklı sınıf sayısını alıyormus
    # ikinci parametre olarak kac tane parametre alacagını her bir giriste.
    # 3. parametre olarak ise vector'un size'ını giris olarak embedded olan vektorun size'ını[1,2,3,1] bu vectorun size'ı 4
    # 3 farklı unique degeri var ve sifrelenince (3,50) lik bir matris verecek bize.
	li = Embedding(n_classes, 50)(in_label) #Shape 1,50
	# scale up to image dimensions with linear activation
    # full connected layer'a veriyoruz ki reshape edebilelim. ilk önce bunda geciriyorlar genellikle.
	n_nodes = in_shape[0] * in_shape[1]  #32x32 = 1024. 
	li = Dense(n_nodes)(li)  #Shape = 1, 1024
	# reshape to additional channel
	li = Reshape((in_shape[0], in_shape[1], 1))(li)  #32x32x1
    
    
	# image input
	in_image = Input(shape=in_shape) #32x32x3
	# concat label as a channel
    # Yukarıdaki olsutudugumuz neural network agının sonucu olan veriyi yani embedded olan veriyi
    # burada concatenate layer'ı ile birlestirerek 4 channel'a sahip fotograflar olusturuyoruz.
	merge = Concatenate()([in_image, li]) #32x32x4 (4 channels, 3 for image and the other for labels)
    
	# downsample: This part is same as unconditional GAN upto the output layer.
    #We will combine input label with input image and supply as inputs to the model. 
    # 128 tane 3x3'luk filtreyi 2ser 2ser saga ve 2ser 2ser asagi atlayarak tarama yap diyoruz.
    
	fe = Conv2D(128, (3,3), strides=(2,2), padding='same')(merge) #16x16x128
	fe = LeakyReLU(alpha=0.2)(fe)
	# downsample
	fe = Conv2D(128, (3,3), strides=(2,2), padding='same')(fe) #8x8x128
	fe = LeakyReLU(alpha=0.2)(fe)
	# flatten feature maps
    # Genellikle buraya daha fazla layer koyarak islem sayisini arttırarak daha fazla eğitime olanak sagliyorlar
    # Ancak burada kısaca kesilmis.
	fe = Flatten()(fe)  #8192  (8*8*128=8192)
	# dropout
	fe = Dropout(0.4)(fe)
	# output
	out_layer = Dense(1, activation='sigmoid')(fe)  #Shape=1
    
	# define model
    ##Combine input label with input image and supply as inputs to the model. 
    # Burada in_label islem gorecek gorecek ve daha sonradan im_image ile bir noktada kesişerek birleşecek.
	model = Model([in_image, in_label], out_layer)
	# compile model
	opt = Adam(learning_rate=0.0002, beta_1=0.5)
	model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
	return model

test_discr = define_discriminator()
print(test_discr.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 1)]                  0         []
#
#  embedding_1 (Embedding)     (None, 1, 50)                500       ['input_3[0][0]']
#
#  dense_2 (Dense)             (None, 1, 1024)              52224     ['embedding_1[0][0]']
#
#  input_4 (InputLayer)        [(None, 32, 32, 3)]          0         []
#
#  reshape_1 (Reshape)         (None, 32, 32, 1)            0         ['dense_2[0][0]']
#
#  concatenate_1 (Concatenate  (None, 32, 32, 4)            0         ['input_4[0][0]',
#  )                                                                   'reshape_1[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 128)          4736      ['concatenate_1[0][0]']
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 16, 16, 128)          0         ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 128)            147584    ['leaky_re_lu_2[0][0]']
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 8, 8, 128)            0         ['conv2d_3[0][0]']
#
#  flatten_1 (Flatten)         (None, 8192)                 0         ['leaky_re_lu_3[0][0]']
#
#  dropout_1 (Dropout)         (None, 8192)                 0         ['flatten_1[0][0]']
#
#  dense_3 (Dense)             (None, 1)                    8193      ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 213237 (832.96 KB)
# Trainable params: 213237 (832.96 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# None

# %% [markdown]
# # 4. Define GENERATOR

# %%
# define the standalone generator model
#latent vector and label as inputs

def define_generator(latent_dim, n_classes=10):
    
	# label input
	in_label = Input(shape=(1,))  #Input of dimension 1
	# embedding for categorical input
    #each label (total 10 classes for cifar), will be represented by a vector of size 50. 
	li = Embedding(n_classes, 50)(in_label) #Shape 1,50
    
	# linear multiplication
	n_nodes = 8 * 8  # To match the dimensions for concatenation later in this step.  
	li = Dense(n_nodes)(li) #1,64
	# reshape to additional channel
	li = Reshape((8, 8, 1))(li)
    
    
	# image generator input
	in_lat = Input(shape=(latent_dim,))  #Input of dimension 100
    
	# foundation for 8x8 image
    # We will reshape input latent vector into 8x8 image as a starting point. 
    #So n_nodes for the Dense layer can be 128x8x8 so when we reshape the output 
    #it would be 8x8x128 and that can be slowly upscaled to 32x32 image for output.
    #Note that this part is same as unconditional GAN until the output layer. 
    #While defining model inputs we will combine input label and the latent input.
	n_nodes = 128 * 8 * 8
	gen = Dense(n_nodes)(in_lat)  #shape=8192
	gen = LeakyReLU(alpha=0.2)(gen)
	gen = Reshape((8, 8, 128))(gen) #Shape=8x8x128
	# merge image gen and label input
	merge = Concatenate()([gen, li])  #Shape=8x8x129 (Extra channel corresponds to the label)
	# upsample to 16x16
    # 128 tane 4x4'luk filtreye haip 2ser 2ser atlayarak tarayan conv2d filtresi.
    # Egerki daha hızlı calısan bir neural network istiyorsan upscaling yaparken conv uygulayan bir layer 
    # yerine upsampling2d kullanarak boyut arttırırken sadece kopyalayarak boyut arttırma yapan layer ile islemlerini 
    # hızlandırabilrsin. Ancak daha iyi sonuclar uretmek icin conv2dTranspose kullanarak upsampling yapmak modeli gelistiriyor.
	gen = Conv2DTranspose(128, (4,4), strides=(2,2), padding='same')(merge) #16x16x128
	gen = LeakyReLU(alpha=0.2)(gen)
	# upsample to 32x32
	gen = Conv2DTranspose(128, (4,4), strides=(2,2), padding='same')(gen) #32x32x128
	gen = LeakyReLU(alpha=0.2)(gen)
	# output
	out_layer = Conv2D(3, (8,8), activation='tanh', padding='same')(gen) #32x32x3
	# define model
	model = Model([in_lat, in_label], out_layer)
	return model   #Model not compiled as it is not directly trained like the discriminator.

test_gen = define_generator(100, n_classes=10)
print(test_gen.summary())
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_6 (InputLayer)        [(None, 100)]                0         []
#
#  input_5 (InputLayer)        [(None, 1)]                  0         []
#
#  dense_5 (Dense)             (None, 8192)                 827392    ['input_6[0][0]']
#
#  embedding_2 (Embedding)     (None, 1, 50)                500       ['input_5[0][0]']
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 8192)                 0         ['dense_5[0][0]']
#
#  dense_4 (Dense)             (None, 1, 64)                3264      ['embedding_2[0][0]']
#
#  reshape_3 (Reshape)         (None, 8, 8, 128)            0         ['leaky_re_lu_4[0][0]']
#
#  reshape_2 (Reshape)         (None, 8, 8, 1)              0         ['dense_4[0][0]']
#
#  concatenate_2 (Concatenate  (None, 8, 8, 129)            0         ['reshape_3[0][0]',
#  )                                                                   'reshape_2[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 16, 16, 128)          264320    ['concatenate_2[0][0]']
#  anspose)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 16, 16, 128)          0         ['conv2d_transpose[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 32, 32, 128)          262272    ['leaky_re_lu_5[0][0]']
#  Transpose)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 32, 32, 128)          0         ['conv2d_transpose_1[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 32, 32, 3)            24579     ['leaky_re_lu_6[0][0]']
#
# ==================================================================================================
# Total params: 1382327 (5.27 MB)
# Trainable params: 1382327 (5.27 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# None

# %% [markdown]
# # 5. Compile GENERATOR and DISCRIMINATOR Together

# %%
# #Generator is trained via GAN combined model. 
# define the combined generator and discriminator model, for updating the generator
#Discriminator is trained separately so here only generator will be trained by keeping
#the discriminator constant. 
def define_gan(g_model, d_model):
	d_model.trainable = False  #Discriminator is trained separately. So set to not trainable.
    
    ## connect generator and discriminator...
	# first, get noise and label inputs from generator model
	gen_noise, gen_label = g_model.input  #Latent vector size and label size
	# get image output from the generator model
	gen_output = g_model.output  #32x32x3
    
	# generator image output and corresponding input label are inputs to discriminator
	gan_output = d_model([gen_output, gen_label])
	# define gan model as taking noise and label and outputting a classification
	model = Model([gen_noise, gen_label], gan_output)
	# compile model
	opt = Adam(learning_rate=0.0002, beta_1=0.5)
	model.compile(loss='binary_crossentropy', optimizer=opt)
	return model

# %% [markdown]
# # 6. Data Preprocessing

# %%
# load cifar images
def load_real_samples():
	# load dataset
	(trainX, trainy), (_, _) = load_data()   #cifar
	# convert to floats and scale
	X = trainX.astype('float32')
	# scale from [0,255] to [-1,1]
	X = (X - 127.5) / 127.5   #Generator uses tanh activation so rescale 
                            #original images to -1 to 1 to match the output of generator.
	return [X, trainy]

# %% [markdown]
# # 7. Take Images from Dataset randomly

# %%
# # select real samples
# pick a batch of random real samples to train the GAN
#In fact, we will train the GAN on a half batch of real images and another 
#half batch of fake images. 
#For each real image we assign a label 1 and for fake we assign label 0. 
def generate_real_samples(dataset, n_samples):
	# split into images and labels
	images, labels = dataset  
	# choose random instances
	ix = randint(0, images.shape[0], n_samples)
	# select images and labels
	X, labels = images[ix], labels[ix]
	# generate class labels and assign to y (don't confuse this with the above labels that correspond to cifar labels)
	y = ones((n_samples, 1))  #Label=1 indicating they are real
    # label ile y farklı seyler
    # y burada predicted value yani gercek mi sahte mi diye soylerken
    # label bu fotografın kategorisini veriyor.
	return [X, labels], y

# %% [markdown]
# # 8. Create Noise and its label

# %%
# generate points in latent space as input for the generator
def generate_latent_points(latent_dim, n_samples, n_classes=10):
	# generate points in the latent space
	x_input = randn(latent_dim * n_samples)
	# reshape into a batch of inputs for the network
	z_input = x_input.reshape(n_samples, latent_dim)
	# generate labels
	labels = randint(0, n_classes, n_samples)
	return [z_input, labels]

# %% [markdown]
# # 9. Create fake images from Noise

# %%
# use the generator to generate n fake examples, with class labels
#Supply the generator, latent_dim and number of samples as input.
#Use the above latent point generator to generate latent points. 
def generate_fake_samples(generator, latent_dim, n_samples):
	# generate points in latent space
	z_input, labels_input = generate_latent_points(latent_dim, n_samples)
	# predict outputs
	images = generator.predict([z_input, labels_input])
	# create class labels
	y = zeros((n_samples, 1))  #Label=0 indicating they are fake
	return [images, labels_input], y

# %% [markdown]
# # 10. Train Function

# %%
# train the generator and discriminator
#We loop through a number of epochs to train our Discriminator by first selecting
#a random batch of images from our true/real dataset.
#Then, generating a set of images using the generator. 
#Feed both set of images into the Discriminator. 
#Finally, set the loss parameters for both the real and fake images, as well as the combined loss. 
def train(g_model, d_model, gan_model, dataset, latent_dim, n_epochs=100, n_batch=128):
	bat_per_epo = int(dataset[0].shape[0] / n_batch)
	half_batch = int(n_batch / 2)  #the discriminator model is updated for a half batch of real samples 
                            #and a half batch of fake samples, combined a single batch. 
	# manually enumerate epochs
	for i in range(n_epochs):
		# enumerate batches over the training set
		for j in range(bat_per_epo):
			
             # Train the discriminator on real and fake images, separately (half batch each)
        #Research showed that separate training is more effective. 
			# get randomly selected 'real' samples
            # get randomly selected 'real' samples
			[X_real, labels_real], y_real = generate_real_samples(dataset, half_batch)

            # update discriminator model weights
            ##train_on_batch allows you to update weights based on a collection 
            #of samples you provide
			d_loss_real, _ = d_model.train_on_batch([X_real, labels_real], y_real)
            
			# generate 'fake' examples
			[X_fake, labels], y_fake = generate_fake_samples(g_model, latent_dim, half_batch)
			# update discriminator model weights
			d_loss_fake, _ = d_model.train_on_batch([X_fake, labels], y_fake)
            
            #d_loss = 0.5 * np.add(d_loss_real, d_loss_fake) #Average loss if you want to report single..
            
			# prepare points in latent space as input for the generator
			[z_input, labels_input] = generate_latent_points(latent_dim, n_batch)
            
            # The generator wants the discriminator to label the generated samples
        # as valid (ones)
        #This is where the generator is trying to trick discriminator into believing
        #the generated image is true (hence value of 1 for y)	
			# create inverted labels for the fake samples
            # Fake image'ler için sonuc label'ini true, real yani 1 yapıyoruz.
            # Genartor ve discirimanotr'ın birlesmesinden olsuan GAN'a bu output labelleri (y_gan) vereceğiz.
			y_gan = ones((n_batch, 1))
             # Generator is part of combined model where it got directly linked with the discriminator
        # Train the generator with latent_dim as x and 1 as y. 
        # Again, 1 as the output as it is adversarial and if generator did a great
        #job of folling the discriminator then the output would be 1 (true)
			# update the generator via the discriminator's error
			g_loss = gan_model.train_on_batch([z_input, labels_input], y_gan)
			# Print losses on this batch
			print('Epoch>%d, Batch%d/%d, d1=%.3f, d2=%.3f g=%.3f' %
				(i+1, j+1, bat_per_epo, d_loss_real, d_loss_fake, g_loss))
	# save the generator model
	g_model.save('cifar_conditional_generator_25epochs.h5')

# %% [markdown]
# # 11. Training

# %%
#Train the GAN

# size of the latent space
latent_dim = 100
# create the discriminator
d_model = define_discriminator()
# create the generator
g_model = define_generator(latent_dim)
# create the gan
gan_model = define_gan(g_model, d_model)
# load image data
dataset = load_real_samples()
# train model
train(g_model, d_model, gan_model, dataset, latent_dim, n_epochs=1)
# Out:
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch1/390, d1=0.710, d2=0.699 g=0.688
# 2/2 [==============================] - 0s 122ms/step
# Epoch>1, Batch2/390, d1=0.648, d2=0.707 g=0.680
# 2/2 [==============================] - 0s 122ms/step
# Epoch>1, Batch3/390, d1=0.599, d2=0.719 g=0.671
# 2/2 [==============================] - 0s 113ms/step
# Epoch>1, Batch4/390, d1=0.553, d2=0.733 g=0.663
# 2/2 [==============================] - 0s 112ms/step
# Epoch>1, Batch5/390, d1=0.498, d2=0.747 g=0.654
# 2/2 [==============================] - 0s 128ms/step
# Epoch>1, Batch6/390, d1=0.469, d2=0.757 g=0.658
# 2/2 [==============================] - 0s 107ms/step
# Epoch>1, Batch7/390, d1=0.404, d2=0.754 g=0.668
# 2/2 [==============================] - 0s 112ms/step
# Epoch>1, Batch8/390, d1=0.397, d2=0.750 g=0.691
# 2/2 [==============================] - 0s 112ms/step
# Epoch>1, Batch9/390, d1=0.316, d2=0.753 g=0.701
# 2/2 [==============================] - 0s 113ms/step
# Epoch>1, Batch10/390, d1=0.324, d2=0.772 g=0.701
# 2/2 [==============================] - 0s 120ms/step
# Epoch>1, Batch11/390, d1=0.282, d2=0.775 g=0.722
# 2/2 [==============================] - 0s 114ms/step
# Epoch>1, Batch12/390, d1=0.303, d2=0.760 g=0.751
# 2/2 [==============================] - 0s 115ms/step
# Epoch>1, Batch13/390, d1=0.288, d2=0.740 g=0.766
# 2/2 [==============================] - 0s 114ms/step
# Epoch>1, Batch14/390, d1=0.299, d2=0.722 g=0.770
# 2/2 [==============================] - 0s 106ms/step
# Epoch>1, Batch15/390, d1=0.402, d2=0.752 g=0.729
# 2/2 [==============================] - 0s 122ms/step
# Epoch>1, Batch16/390, d1=0.427, d2=0.814 g=0.669
# 2/2 [==============================] - 0s 118ms/step
# Epoch>1, Batch17/390, d1=0.328, d2=0.912 g=0.622
# 2/2 [==============================] - 0s 121ms/step
# Epoch>1, Batch18/390, d1=0.301, d2=1.054 g=0.573
# 2/2 [==============================] - 0s 116ms/step
# Epoch>1, Batch19/390, d1=0.313, d2=1.190 g=0.543
# 2/2 [==============================] - 0s 117ms/step
# Epoch>1, Batch20/390, d1=0.321, d2=1.173 g=0.568
# 2/2 [==============================] - 0s 114ms/step
# Epoch>1, Batch21/390, d1=0.337, d2=1.020 g=0.686
# 2/2 [==============================] - 0s 139ms/step
# Epoch>1, Batch22/390, d1=0.255, d2=0.833 g=0.850
# 2/2 [==============================] - 0s 113ms/step
# Epoch>1, Batch23/390, d1=0.279, d2=0.784 g=0.932
# 2/2 [==============================] - 0s 111ms/step
# Epoch>1, Batch24/390, d1=0.262, d2=0.773 g=0.952
# 2/2 [==============================] - 0s 142ms/step
# Epoch>1, Batch25/390, d1=0.284, d2=0.754 g=1.020
# 2/2 [==============================] - 0s 145ms/step
# Epoch>1, Batch26/390, d1=0.289, d2=0.678 g=1.088
# 2/2 [==============================] - 0s 143ms/step
# Epoch>1, Batch27/390, d1=0.326, d2=0.642 g=1.040
# 2/2 [==============================] - 0s 120ms/step
# Epoch>1, Batch28/390, d1=0.308, d2=0.711 g=0.907
# 2/2 [==============================] - 0s 143ms/step
# Epoch>1, Batch29/390, d1=0.378, d2=0.834 g=0.755
# 2/2 [==============================] - 0s 116ms/step
# Epoch>1, Batch30/390, d1=0.436, d2=1.016 g=0.609
# 2/2 [==============================] - 0s 136ms/step
# Epoch>1, Batch31/390, d1=0.444, d2=1.137 g=0.567
# 2/2 [==============================] - 0s 106ms/step
# Epoch>1, Batch32/390, d1=0.471, d2=1.201 g=0.564
# 2/2 [==============================] - 0s 113ms/step
# Epoch>1, Batch33/390, d1=0.445, d2=1.118 g=0.634
# 2/2 [==============================] - 0s 112ms/step
# Epoch>1, Batch34/390, d1=0.442, d2=1.010 g=0.713
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch35/390, d1=0.492, d2=0.961 g=0.785
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch36/390, d1=0.723, d2=0.909 g=0.850
# 2/2 [==============================] - 0s 111ms/step
# Epoch>1, Batch37/390, d1=0.670, d2=0.826 g=0.929
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch38/390, d1=0.699, d2=0.731 g=1.025
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch39/390, d1=0.760, d2=0.598 g=1.128
# 2/2 [==============================] - 0s 112ms/step
# Epoch>1, Batch40/390, d1=0.777, d2=0.575 g=1.082
# 2/2 [==============================] - 0s 116ms/step
# Epoch>1, Batch41/390, d1=0.813, d2=0.626 g=0.947
# 2/2 [==============================] - 0s 108ms/step
# Epoch>1, Batch42/390, d1=0.885, d2=0.685 g=0.802
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch43/390, d1=0.719, d2=0.695 g=0.792
# 2/2 [==============================] - 0s 113ms/step
# Epoch>1, Batch44/390, d1=0.688, d2=0.678 g=0.807
# 2/2 [==============================] - 0s 134ms/step
# Epoch>1, Batch45/390, d1=0.646, d2=0.635 g=0.854
# 2/2 [==============================] - 0s 113ms/step
# Epoch>1, Batch46/390, d1=0.617, d2=0.581 g=0.922
# 2/2 [==============================] - 0s 112ms/step
# Epoch>1, Batch47/390, d1=0.513, d2=0.527 g=1.004
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch48/390, d1=0.504, d2=0.483 g=1.093
# 2/2 [==============================] - 0s 105ms/step
# Epoch>1, Batch49/390, d1=0.365, d2=0.451 g=1.140
# 2/2 [==============================] - 0s 120ms/step
# Epoch>1, Batch50/390, d1=0.397, d2=0.473 g=1.101
# 2/2 [==============================] - 0s 117ms/step
# Epoch>1, Batch51/390, d1=0.336, d2=0.574 g=0.984
# 2/2 [==============================] - 0s 111ms/step
# Epoch>1, Batch52/390, d1=0.326, d2=0.742 g=0.819
# 2/2 [==============================] - 0s 120ms/step
# Epoch>1, Batch53/390, d1=0.261, d2=0.927 g=0.709
# 2/2 [==============================] - 0s 116ms/step
# Epoch>1, Batch54/390, d1=0.302, d2=0.959 g=0.704
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch55/390, d1=0.334, d2=0.931 g=0.763
# 2/2 [==============================] - 0s 114ms/step
# Epoch>1, Batch56/390, d1=0.361, d2=0.871 g=0.770
# 2/2 [==============================] - 0s 112ms/step
# Epoch>1, Batch57/390, d1=0.448, d2=0.806 g=0.774
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch58/390, d1=0.454, d2=0.780 g=0.806
# 2/2 [==============================] - 0s 111ms/step
# Epoch>1, Batch59/390, d1=0.528, d2=0.754 g=0.809
# 2/2 [==============================] - 0s 108ms/step
# Epoch>1, Batch60/390, d1=0.624, d2=0.744 g=0.824
# 2/2 [==============================] - 0s 125ms/step
# Epoch>1, Batch61/390, d1=0.449, d2=0.688 g=0.900
# 2/2 [==============================] - 0s 106ms/step
# Epoch>1, Batch62/390, d1=0.450, d2=0.584 g=1.016
# 2/2 [==============================] - 0s 107ms/step
# Epoch>1, Batch63/390, d1=0.381, d2=0.487 g=1.166
# 2/2 [==============================] - 0s 117ms/step
# Epoch>1, Batch64/390, d1=0.459, d2=0.450 g=1.207
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch65/390, d1=0.417, d2=0.486 g=1.150
# 2/2 [==============================] - 0s 107ms/step
# Epoch>1, Batch66/390, d1=0.409, d2=0.594 g=0.963
# 2/2 [==============================] - 0s 117ms/step
# Epoch>1, Batch67/390, d1=0.369, d2=0.781 g=0.730
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch68/390, d1=0.410, d2=1.008 g=0.588
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch69/390, d1=0.415, d2=1.112 g=0.547
# 2/2 [==============================] - 0s 113ms/step
# Epoch>1, Batch70/390, d1=0.392, d2=1.092 g=0.606
# 2/2 [==============================] - 0s 107ms/step
# Epoch>1, Batch71/390, d1=0.468, d2=0.944 g=0.728
# 2/2 [==============================] - 0s 107ms/step
# Epoch>1, Batch72/390, d1=0.491, d2=0.735 g=0.883
# 2/2 [==============================] - 0s 107ms/step
# Epoch>1, Batch73/390, d1=0.551, d2=0.596 g=1.044
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch74/390, d1=0.563, d2=0.487 g=1.166
# 2/2 [==============================] - 0s 112ms/step
# Epoch>1, Batch75/390, d1=0.525, d2=0.408 g=1.300
# 2/2 [==============================] - 0s 115ms/step
# Epoch>1, Batch76/390, d1=0.510, d2=0.370 g=1.392
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch77/390, d1=0.493, d2=0.357 g=1.375
# 2/2 [==============================] - 0s 107ms/step
# Epoch>1, Batch78/390, d1=0.410, d2=0.363 g=1.368
# 2/2 [==============================] - 0s 108ms/step
# Epoch>1, Batch79/390, d1=0.409, d2=0.402 g=1.255
# 2/2 [==============================] - 0s 112ms/step
# Epoch>1, Batch80/390, d1=0.368, d2=0.450 g=1.166
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch81/390, d1=0.403, d2=0.516 g=1.024
# 2/2 [==============================] - 0s 115ms/step
# Epoch>1, Batch82/390, d1=0.319, d2=0.570 g=0.950
# 2/2 [==============================] - 0s 135ms/step
# Epoch>1, Batch83/390, d1=0.442, d2=0.603 g=0.860
# 2/2 [==============================] - 0s 112ms/step
# Epoch>1, Batch84/390, d1=0.349, d2=0.603 g=0.854
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch85/390, d1=0.428, d2=0.600 g=0.850
# 2/2 [==============================] - 0s 111ms/step
# Epoch>1, Batch86/390, d1=0.323, d2=0.580 g=0.857
# 2/2 [==============================] - 0s 114ms/step
# Epoch>1, Batch87/390, d1=0.259, d2=0.575 g=0.886
# 2/2 [==============================] - 0s 114ms/step
# Epoch>1, Batch88/390, d1=0.381, d2=0.562 g=0.877
# 2/2 [==============================] - 0s 114ms/step
# Epoch>1, Batch89/390, d1=0.381, d2=0.568 g=0.870
# 2/2 [==============================] - 0s 123ms/step
# Epoch>1, Batch90/390, d1=0.281, d2=0.576 g=0.859
# 2/2 [==============================] - 0s 115ms/step
# Epoch>1, Batch91/390, d1=0.271, d2=0.573 g=0.856
# 2/2 [==============================] - 0s 111ms/step
# Epoch>1, Batch92/390, d1=0.236, d2=0.575 g=0.857
# 2/2 [==============================] - 0s 108ms/step
# Epoch>1, Batch93/390, d1=0.202, d2=0.576 g=0.856
# 2/2 [==============================] - 0s 123ms/step
# Epoch>1, Batch94/390, d1=0.242, d2=0.574 g=0.852
# 2/2 [==============================] - 0s 113ms/step
# Epoch>1, Batch95/390, d1=0.230, d2=0.586 g=0.838
# 2/2 [==============================] - 0s 112ms/step
# Epoch>1, Batch96/390, d1=0.173, d2=0.601 g=0.824
# 2/2 [==============================] - 0s 112ms/step
# Epoch>1, Batch97/390, d1=0.158, d2=0.622 g=0.803
# 2/2 [==============================] - 0s 117ms/step
# Epoch>1, Batch98/390, d1=0.134, d2=0.690 g=0.750
# 2/2 [==============================] - 0s 124ms/step
# Epoch>1, Batch99/390, d1=0.117, d2=0.872 g=0.627
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch100/390, d1=0.118, d2=1.132 g=0.490
# 2/2 [==============================] - 0s 111ms/step
# Epoch>1, Batch101/390, d1=0.108, d2=1.407 g=0.459
# 2/2 [==============================] - 0s 106ms/step
# Epoch>1, Batch102/390, d1=0.142, d2=1.280 g=0.624
# 2/2 [==============================] - 0s 106ms/step
# Epoch>1, Batch103/390, d1=0.125, d2=0.814 g=1.044
# 2/2 [==============================] - 0s 113ms/step
# Epoch>1, Batch104/390, d1=0.190, d2=0.414 g=1.609
# 2/2 [==============================] - 0s 117ms/step
# Epoch>1, Batch105/390, d1=0.258, d2=0.237 g=1.990
# 2/2 [==============================] - 0s 124ms/step
# Epoch>1, Batch106/390, d1=0.306, d2=0.231 g=1.804
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch107/390, d1=0.354, d2=0.306 g=1.547
# 2/2 [==============================] - 0s 120ms/step
# Epoch>1, Batch108/390, d1=0.306, d2=0.356 g=1.379
# 2/2 [==============================] - 0s 108ms/step
# Epoch>1, Batch109/390, d1=0.340, d2=0.416 g=1.219
# 2/2 [==============================] - 0s 108ms/step
# Epoch>1, Batch110/390, d1=0.279, d2=0.466 g=1.097
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch111/390, d1=0.253, d2=0.497 g=1.021
# 2/2 [==============================] - 0s 107ms/step
# Epoch>1, Batch112/390, d1=0.217, d2=0.534 g=0.964
# 2/2 [==============================] - 0s 120ms/step
# Epoch>1, Batch113/390, d1=0.267, d2=0.601 g=0.896
# 2/2 [==============================] - 0s 112ms/step
# Epoch>1, Batch114/390, d1=0.286, d2=0.725 g=0.804
# 2/2 [==============================] - 0s 129ms/step
# Epoch>1, Batch115/390, d1=0.170, d2=0.878 g=0.744
# 2/2 [==============================] - 0s 108ms/step
# Epoch>1, Batch116/390, d1=0.274, d2=1.031 g=0.792
# 2/2 [==============================] - 0s 123ms/step
# Epoch>1, Batch117/390, d1=0.225, d2=0.863 g=1.015
# 2/2 [==============================] - 0s 115ms/step
# Epoch>1, Batch118/390, d1=0.245, d2=0.695 g=1.321
# 2/2 [==============================] - 0s 112ms/step
# Epoch>1, Batch119/390, d1=0.258, d2=0.633 g=1.586
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch120/390, d1=0.307, d2=0.590 g=1.852
# 2/2 [==============================] - 0s 113ms/step
# Epoch>1, Batch121/390, d1=0.512, d2=0.411 g=2.146
# 2/2 [==============================] - 0s 123ms/step
# Epoch>1, Batch122/390, d1=0.636, d2=0.275 g=2.363
# 2/2 [==============================] - 0s 125ms/step
# Epoch>1, Batch123/390, d1=0.811, d2=0.292 g=2.023
# 2/2 [==============================] - 0s 131ms/step
# Epoch>1, Batch124/390, d1=0.645, d2=0.293 g=1.943
# 2/2 [==============================] - 0s 123ms/step
# Epoch>1, Batch125/390, d1=0.777, d2=0.400 g=1.600
# 2/2 [==============================] - 0s 120ms/step
# Epoch>1, Batch126/390, d1=0.694, d2=0.644 g=1.249
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch127/390, d1=0.593, d2=0.796 g=1.000
# 2/2 [==============================] - 0s 112ms/step
# Epoch>1, Batch128/390, d1=0.719, d2=0.669 g=1.105
# 2/2 [==============================] - 0s 107ms/step
# Epoch>1, Batch129/390, d1=0.816, d2=0.462 g=1.346
# 2/2 [==============================] - 0s 114ms/step
# Epoch>1, Batch130/390, d1=0.550, d2=0.320 g=1.565
# 2/2 [==============================] - 0s 116ms/step
# Epoch>1, Batch131/390, d1=0.359, d2=0.267 g=1.717
# 2/2 [==============================] - 0s 106ms/step
# Epoch>1, Batch132/390, d1=0.339, d2=0.241 g=1.690
# 2/2 [==============================] - 0s 111ms/step
# Epoch>1, Batch133/390, d1=0.223, d2=0.259 g=1.661
# 2/2 [==============================] - 0s 114ms/step
# Epoch>1, Batch134/390, d1=0.316, d2=0.275 g=1.556
# 2/2 [==============================] - 0s 116ms/step
# Epoch>1, Batch135/390, d1=0.266, d2=0.296 g=1.491
# 2/2 [==============================] - 0s 116ms/step
# Epoch>1, Batch136/390, d1=0.243, d2=0.316 g=1.421
# 2/2 [==============================] - 0s 111ms/step
# Epoch>1, Batch137/390, d1=0.217, d2=0.345 g=1.336
# 2/2 [==============================] - 0s 120ms/step
# Epoch>1, Batch138/390, d1=0.167, d2=0.358 g=1.267
# 2/2 [==============================] - 0s 116ms/step
# Epoch>1, Batch139/390, d1=0.112, d2=0.377 g=1.239
# 2/2 [==============================] - 0s 112ms/step
# Epoch>1, Batch140/390, d1=0.149, d2=0.389 g=1.203
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch141/390, d1=0.170, d2=0.409 g=1.147
# 2/2 [==============================] - 0s 111ms/step
# Epoch>1, Batch142/390, d1=0.106, d2=0.416 g=1.134
# 2/2 [==============================] - 0s 131ms/step
# Epoch>1, Batch143/390, d1=0.120, d2=0.426 g=1.115
# 2/2 [==============================] - 0s 149ms/step
# Epoch>1, Batch144/390, d1=0.097, d2=0.431 g=1.104
# 2/2 [==============================] - 0s 115ms/step
# Epoch>1, Batch145/390, d1=0.081, d2=0.433 g=1.107
# 2/2 [==============================] - 0s 117ms/step
# Epoch>1, Batch146/390, d1=0.141, d2=0.436 g=1.109
# 2/2 [==============================] - 0s 111ms/step
# Epoch>1, Batch147/390, d1=0.106, d2=0.437 g=1.107
# 2/2 [==============================] - 0s 111ms/step
# Epoch>1, Batch148/390, d1=0.083, d2=0.433 g=1.119
# 2/2 [==============================] - 0s 113ms/step
# Epoch>1, Batch149/390, d1=0.134, d2=0.438 g=1.112
# 2/2 [==============================] - 0s 108ms/step
# Epoch>1, Batch150/390, d1=0.099, d2=0.454 g=1.117
# 2/2 [==============================] - 0s 111ms/step
# Epoch>1, Batch151/390, d1=0.087, d2=0.489 g=1.078
# 2/2 [==============================] - 0s 107ms/step
# Epoch>1, Batch152/390, d1=0.133, d2=0.565 g=1.021
# 2/2 [==============================] - 0s 112ms/step
# Epoch>1, Batch153/390, d1=0.091, d2=0.784 g=0.950
# 2/2 [==============================] - 0s 114ms/step
# Epoch>1, Batch154/390, d1=0.100, d2=0.936 g=1.051
# 2/2 [==============================] - 0s 112ms/step
# Epoch>1, Batch155/390, d1=0.165, d2=0.942 g=1.399
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch156/390, d1=0.177, d2=0.557 g=1.854
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch157/390, d1=0.280, d2=0.373 g=2.327
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch158/390, d1=0.443, d2=0.232 g=2.451
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch159/390, d1=0.519, d2=0.229 g=2.199
# 2/2 [==============================] - 0s 115ms/step
# Epoch>1, Batch160/390, d1=0.433, d2=0.226 g=2.235
# 2/2 [==============================] - 0s 111ms/step
# Epoch>1, Batch161/390, d1=0.558, d2=0.244 g=1.816
# 2/2 [==============================] - 0s 111ms/step
# Epoch>1, Batch162/390, d1=0.445, d2=0.307 g=1.689
# 2/2 [==============================] - 0s 106ms/step
# Epoch>1, Batch163/390, d1=0.375, d2=0.322 g=1.650
# 2/2 [==============================] - 0s 106ms/step
# Epoch>1, Batch164/390, d1=0.237, d2=0.275 g=1.722
# 2/2 [==============================] - 0s 108ms/step
# Epoch>1, Batch165/390, d1=0.324, d2=0.263 g=1.814
# 2/2 [==============================] - 0s 107ms/step
# Epoch>1, Batch166/390, d1=0.285, d2=0.359 g=1.760
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch167/390, d1=0.408, d2=0.410 g=1.484
# 2/2 [==============================] - 0s 108ms/step
# Epoch>1, Batch168/390, d1=0.164, d2=0.600 g=1.483
# 2/2 [==============================] - 0s 106ms/step
# Epoch>1, Batch169/390, d1=0.260, d2=0.550 g=1.362
# 2/2 [==============================] - 0s 120ms/step
# Epoch>1, Batch170/390, d1=0.305, d2=0.936 g=1.408
# 2/2 [==============================] - 0s 108ms/step
# Epoch>1, Batch171/390, d1=0.274, d2=0.875 g=1.217
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch172/390, d1=0.289, d2=0.876 g=1.232
# 2/2 [==============================] - 0s 111ms/step
# Epoch>1, Batch173/390, d1=0.257, d2=0.706 g=1.209
# 2/2 [==============================] - 0s 112ms/step
# Epoch>1, Batch174/390, d1=0.264, d2=0.711 g=1.118
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch175/390, d1=0.346, d2=0.875 g=1.255
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch176/390, d1=0.471, d2=0.704 g=1.223
# 2/2 [==============================] - 0s 106ms/step
# Epoch>1, Batch177/390, d1=0.438, d2=0.626 g=1.237
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch178/390, d1=0.623, d2=0.566 g=1.242
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch179/390, d1=0.508, d2=0.708 g=1.308
# 2/2 [==============================] - 0s 116ms/step
# Epoch>1, Batch180/390, d1=0.645, d2=0.544 g=1.398
# 2/2 [==============================] - 0s 108ms/step
# Epoch>1, Batch181/390, d1=0.973, d2=0.549 g=1.454
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch182/390, d1=0.645, d2=0.436 g=1.623
# 2/2 [==============================] - 0s 105ms/step
# Epoch>1, Batch183/390, d1=0.804, d2=0.380 g=1.708
# 2/2 [==============================] - 0s 114ms/step
# Epoch>1, Batch184/390, d1=0.879, d2=0.448 g=1.692
# 2/2 [==============================] - 0s 115ms/step
# Epoch>1, Batch185/390, d1=0.600, d2=0.363 g=1.735
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch186/390, d1=0.895, d2=0.399 g=1.574
# 2/2 [==============================] - 0s 117ms/step
# Epoch>1, Batch187/390, d1=0.805, d2=0.535 g=1.593
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch188/390, d1=0.676, d2=0.392 g=1.654
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch189/390, d1=0.928, d2=0.392 g=1.633
# 2/2 [==============================] - 0s 112ms/step
# Epoch>1, Batch190/390, d1=0.691, d2=0.380 g=1.800
# 2/2 [==============================] - 0s 108ms/step
# Epoch>1, Batch191/390, d1=0.930, d2=0.390 g=1.537
# 2/2 [==============================] - 0s 111ms/step
# Epoch>1, Batch192/390, d1=0.767, d2=0.553 g=1.575
# 2/2 [==============================] - 0s 108ms/step
# Epoch>1, Batch193/390, d1=0.787, d2=0.500 g=1.694
# 2/2 [==============================] - 0s 113ms/step
# Epoch>1, Batch194/390, d1=0.804, d2=0.458 g=1.637
# 2/2 [==============================] - 0s 118ms/step
# Epoch>1, Batch195/390, d1=0.715, d2=0.495 g=1.739
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch196/390, d1=0.698, d2=0.437 g=1.716
# 2/2 [==============================] - 0s 112ms/step
# Epoch>1, Batch197/390, d1=0.904, d2=0.374 g=1.683
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch198/390, d1=0.795, d2=0.440 g=1.630
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch199/390, d1=0.835, d2=0.486 g=1.571
# 2/2 [==============================] - 0s 116ms/step
# Epoch>1, Batch200/390, d1=0.854, d2=0.442 g=1.512
# 2/2 [==============================] - 0s 108ms/step
# Epoch>1, Batch201/390, d1=0.761, d2=0.433 g=1.490
# 2/2 [==============================] - 0s 113ms/step
# Epoch>1, Batch202/390, d1=0.764, d2=0.515 g=1.508
# 2/2 [==============================] - 0s 112ms/step
# Epoch>1, Batch203/390, d1=0.908, d2=0.406 g=1.506
# 2/2 [==============================] - 0s 121ms/step
# Epoch>1, Batch204/390, d1=0.790, d2=0.482 g=1.440
# 2/2 [==============================] - 0s 113ms/step
# Epoch>1, Batch205/390, d1=0.778, d2=0.428 g=1.366
# 2/2 [==============================] - 0s 121ms/step
# Epoch>1, Batch206/390, d1=0.788, d2=0.496 g=1.428
# 2/2 [==============================] - 0s 112ms/step
# Epoch>1, Batch207/390, d1=0.787, d2=0.455 g=1.375
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch208/390, d1=0.819, d2=0.447 g=1.337
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch209/390, d1=0.672, d2=0.453 g=1.383
# 2/2 [==============================] - 0s 113ms/step
# Epoch>1, Batch210/390, d1=0.800, d2=0.495 g=1.394
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch211/390, d1=0.726, d2=0.438 g=1.251
# 2/2 [==============================] - 0s 108ms/step
# Epoch>1, Batch212/390, d1=0.853, d2=0.486 g=1.220
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch213/390, d1=0.810, d2=0.577 g=1.149
# 2/2 [==============================] - 0s 147ms/step
# Epoch>1, Batch214/390, d1=0.639, d2=0.635 g=1.184
# 2/2 [==============================] - 0s 113ms/step
# Epoch>1, Batch215/390, d1=0.769, d2=0.577 g=1.159
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch216/390, d1=0.802, d2=0.610 g=1.089
# 2/2 [==============================] - 0s 108ms/step
# Epoch>1, Batch217/390, d1=0.702, d2=0.493 g=1.034
# 2/2 [==============================] - 0s 115ms/step
# Epoch>1, Batch218/390, d1=0.702, d2=0.524 g=1.066
# 2/2 [==============================] - 0s 111ms/step
# Epoch>1, Batch219/390, d1=0.667, d2=0.599 g=1.131
# 2/2 [==============================] - 0s 112ms/step
# Epoch>1, Batch220/390, d1=0.710, d2=0.588 g=1.165
# 2/2 [==============================] - 0s 121ms/step
# Epoch>1, Batch221/390, d1=0.745, d2=0.545 g=1.209
# 2/2 [==============================] - 0s 111ms/step
# Epoch>1, Batch222/390, d1=0.758, d2=0.605 g=1.094
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch223/390, d1=0.680, d2=0.578 g=1.199
# 2/2 [==============================] - 0s 107ms/step
# Epoch>1, Batch224/390, d1=0.790, d2=0.616 g=1.114
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch225/390, d1=0.758, d2=0.652 g=1.036
# 2/2 [==============================] - 0s 114ms/step
# Epoch>1, Batch226/390, d1=0.840, d2=0.656 g=0.976
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch227/390, d1=0.722, d2=0.704 g=1.078
# 2/2 [==============================] - 0s 114ms/step
# Epoch>1, Batch228/390, d1=0.762, d2=0.659 g=1.023
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch229/390, d1=0.810, d2=0.635 g=1.020
# 2/2 [==============================] - 0s 107ms/step
# Epoch>1, Batch230/390, d1=0.916, d2=0.769 g=0.935
# 2/2 [==============================] - 0s 126ms/step
# Epoch>1, Batch231/390, d1=0.815, d2=0.705 g=0.948
# 2/2 [==============================] - 0s 108ms/step
# Epoch>1, Batch232/390, d1=0.868, d2=0.652 g=0.950
# 2/2 [==============================] - 0s 106ms/step
# Epoch>1, Batch233/390, d1=0.773, d2=0.645 g=0.969
# 2/2 [==============================] - 0s 116ms/step
# Epoch>1, Batch234/390, d1=0.783, d2=0.620 g=1.021
# 2/2 [==============================] - 0s 139ms/step
# Epoch>1, Batch235/390, d1=0.749, d2=0.668 g=1.093
# 2/2 [==============================] - 0s 116ms/step
# Epoch>1, Batch236/390, d1=0.789, d2=0.537 g=1.152
# 2/2 [==============================] - 0s 111ms/step
# Epoch>1, Batch237/390, d1=0.781, d2=0.480 g=1.150
# 2/2 [==============================] - 0s 111ms/step
# Epoch>1, Batch238/390, d1=0.729, d2=0.475 g=1.275
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch239/390, d1=0.726, d2=0.439 g=1.333
# 2/2 [==============================] - 0s 120ms/step
# Epoch>1, Batch240/390, d1=0.637, d2=0.395 g=1.375
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch241/390, d1=0.670, d2=0.422 g=1.325
# 2/2 [==============================] - 0s 124ms/step
# Epoch>1, Batch242/390, d1=0.546, d2=0.445 g=1.295
# 2/2 [==============================] - 0s 120ms/step
# Epoch>1, Batch243/390, d1=0.664, d2=0.532 g=1.195
# 2/2 [==============================] - 0s 117ms/step
# Epoch>1, Batch244/390, d1=0.485, d2=0.552 g=1.376
# 2/2 [==============================] - 0s 117ms/step
# Epoch>1, Batch245/390, d1=0.529, d2=0.413 g=1.585
# 2/2 [==============================] - 0s 134ms/step
# Epoch>1, Batch246/390, d1=0.762, d2=0.327 g=1.644
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch247/390, d1=0.616, d2=0.411 g=1.589
# 2/2 [==============================] - 0s 112ms/step
# Epoch>1, Batch248/390, d1=0.597, d2=0.510 g=1.267
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch249/390, d1=0.777, d2=0.842 g=1.046
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch250/390, d1=0.792, d2=0.892 g=0.847
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch251/390, d1=1.059, d2=0.893 g=0.942
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch252/390, d1=1.012, d2=0.726 g=1.071
# 2/2 [==============================] - 0s 111ms/step
# Epoch>1, Batch253/390, d1=1.023, d2=0.880 g=1.086
# 2/2 [==============================] - 0s 120ms/step
# Epoch>1, Batch254/390, d1=0.969, d2=0.809 g=1.117
# 2/2 [==============================] - 0s 128ms/step
# Epoch>1, Batch255/390, d1=1.182, d2=0.796 g=1.260
# 2/2 [==============================] - 0s 153ms/step
# Epoch>1, Batch256/390, d1=1.142, d2=0.535 g=1.564
# 2/2 [==============================] - 0s 116ms/step
# Epoch>1, Batch257/390, d1=1.224, d2=0.336 g=1.863
# 2/2 [==============================] - 0s 145ms/step
# Epoch>1, Batch258/390, d1=1.149, d2=0.315 g=1.751
# 2/2 [==============================] - 0s 135ms/step
# Epoch>1, Batch259/390, d1=1.087, d2=0.325 g=1.724
# 2/2 [==============================] - 0s 143ms/step
# Epoch>1, Batch260/390, d1=0.739, d2=0.288 g=1.854
# 2/2 [==============================] - 0s 107ms/step
# Epoch>1, Batch261/390, d1=0.792, d2=0.325 g=1.727
# 2/2 [==============================] - 0s 116ms/step
# Epoch>1, Batch262/390, d1=0.735, d2=0.419 g=1.561
# 2/2 [==============================] - 0s 138ms/step
# Epoch>1, Batch263/390, d1=0.798, d2=0.460 g=1.324
# 2/2 [==============================] - 0s 119ms/step
# Epoch>1, Batch264/390, d1=0.814, d2=0.560 g=1.150
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch265/390, d1=0.724, d2=0.655 g=1.026
# 2/2 [==============================] - 0s 113ms/step
# Epoch>1, Batch266/390, d1=0.800, d2=0.724 g=0.975
# 2/2 [==============================] - 0s 111ms/step
# Epoch>1, Batch267/390, d1=0.728, d2=0.661 g=0.975
# 2/2 [==============================] - 0s 116ms/step
# Epoch>1, Batch268/390, d1=0.849, d2=0.622 g=0.991
# 2/2 [==============================] - 0s 114ms/step
# Epoch>1, Batch269/390, d1=0.905, d2=0.660 g=1.021
# 2/2 [==============================] - 0s 107ms/step
# Epoch>1, Batch270/390, d1=0.881, d2=0.615 g=1.049
# 2/2 [==============================] - 0s 108ms/step
# Epoch>1, Batch271/390, d1=0.886, d2=0.643 g=1.026
# 2/2 [==============================] - 0s 108ms/step
# Epoch>1, Batch272/390, d1=0.929, d2=0.621 g=1.050
# 2/2 [==============================] - 0s 141ms/step
# Epoch>1, Batch273/390, d1=0.920, d2=0.613 g=1.067
# 2/2 [==============================] - 0s 112ms/step
# Epoch>1, Batch274/390, d1=0.958, d2=0.580 g=1.035
# 2/2 [==============================] - 0s 111ms/step
# Epoch>1, Batch275/390, d1=0.970, d2=0.530 g=1.111
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch276/390, d1=0.945, d2=0.554 g=1.216
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch277/390, d1=0.960, d2=0.514 g=1.181
# 2/2 [==============================] - 0s 108ms/step
# Epoch>1, Batch278/390, d1=0.921, d2=0.460 g=1.174
# 2/2 [==============================] - 0s 113ms/step
# Epoch>1, Batch279/390, d1=0.916, d2=0.457 g=1.153
# 2/2 [==============================] - 0s 124ms/step
# Epoch>1, Batch280/390, d1=0.819, d2=0.498 g=1.226
# 2/2 [==============================] - 0s 125ms/step
# Epoch>1, Batch281/390, d1=0.873, d2=0.451 g=1.206
# 2/2 [==============================] - 0s 111ms/step
# Epoch>1, Batch282/390, d1=0.844, d2=0.449 g=1.297
# 2/2 [==============================] - 0s 111ms/step
# Epoch>1, Batch283/390, d1=0.870, d2=0.446 g=1.166
# 2/2 [==============================] - 0s 107ms/step
# Epoch>1, Batch284/390, d1=0.828, d2=0.487 g=1.237
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch285/390, d1=0.765, d2=0.459 g=1.229
# 2/2 [==============================] - 0s 117ms/step
# Epoch>1, Batch286/390, d1=0.792, d2=0.416 g=1.159
# 2/2 [==============================] - 0s 117ms/step
# Epoch>1, Batch287/390, d1=0.765, d2=0.474 g=1.169
# 2/2 [==============================] - 0s 108ms/step
# Epoch>1, Batch288/390, d1=0.778, d2=0.482 g=1.149
# 2/2 [==============================] - 0s 106ms/step
# Epoch>1, Batch289/390, d1=0.769, d2=0.476 g=1.119
# 2/2 [==============================] - 0s 131ms/step
# Epoch>1, Batch290/390, d1=0.735, d2=0.506 g=1.092
# 2/2 [==============================] - 0s 174ms/step
# Epoch>1, Batch291/390, d1=0.793, d2=0.575 g=1.072
# 2/2 [==============================] - 0s 128ms/step
# Epoch>1, Batch292/390, d1=0.817, d2=0.529 g=1.057
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch293/390, d1=0.785, d2=0.529 g=1.059
# 2/2 [==============================] - 0s 125ms/step
# Epoch>1, Batch294/390, d1=0.772, d2=0.504 g=1.061
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch295/390, d1=0.799, d2=0.534 g=0.986
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch296/390, d1=0.784, d2=0.544 g=1.032
# 2/2 [==============================] - 0s 111ms/step
# Epoch>1, Batch297/390, d1=0.789, d2=0.575 g=1.051
# 2/2 [==============================] - 0s 112ms/step
# Epoch>1, Batch298/390, d1=0.774, d2=0.529 g=1.079
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch299/390, d1=0.781, d2=0.525 g=1.070
# 2/2 [==============================] - 0s 121ms/step
# Epoch>1, Batch300/390, d1=0.801, d2=0.510 g=1.072
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch301/390, d1=0.782, d2=0.507 g=1.128
# 2/2 [==============================] - 0s 118ms/step
# Epoch>1, Batch302/390, d1=0.800, d2=0.517 g=1.108
# 2/2 [==============================] - 0s 108ms/step
# Epoch>1, Batch303/390, d1=0.733, d2=0.519 g=1.171
# 2/2 [==============================] - 0s 106ms/step
# Epoch>1, Batch304/390, d1=0.806, d2=0.498 g=1.122
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch305/390, d1=0.733, d2=0.499 g=1.158
# 2/2 [==============================] - 0s 111ms/step
# Epoch>1, Batch306/390, d1=0.737, d2=0.454 g=1.050
# 2/2 [==============================] - 0s 112ms/step
# Epoch>1, Batch307/390, d1=0.791, d2=0.556 g=1.107
# 2/2 [==============================] - 0s 115ms/step
# Epoch>1, Batch308/390, d1=0.740, d2=0.482 g=1.062
# 2/2 [==============================] - 0s 111ms/step
# Epoch>1, Batch309/390, d1=0.707, d2=0.575 g=1.037
# 2/2 [==============================] - 0s 108ms/step
# Epoch>1, Batch310/390, d1=0.740, d2=0.511 g=1.038
# 2/2 [==============================] - 0s 106ms/step
# Epoch>1, Batch311/390, d1=0.728, d2=0.588 g=1.031
# 2/2 [==============================] - 0s 108ms/step
# Epoch>1, Batch312/390, d1=0.768, d2=0.536 g=1.019
# 2/2 [==============================] - 0s 104ms/step
# Epoch>1, Batch313/390, d1=0.754, d2=0.596 g=0.999
# 2/2 [==============================] - 0s 116ms/step
# Epoch>1, Batch314/390, d1=0.767, d2=0.598 g=0.973
# 2/2 [==============================] - 0s 111ms/step
# Epoch>1, Batch315/390, d1=0.752, d2=0.588 g=0.905
# 2/2 [==============================] - 0s 103ms/step
# Epoch>1, Batch316/390, d1=0.774, d2=0.639 g=0.876
# 2/2 [==============================] - 0s 111ms/step
# Epoch>1, Batch317/390, d1=0.802, d2=0.628 g=0.924
# 2/2 [==============================] - 0s 112ms/step
# Epoch>1, Batch318/390, d1=0.825, d2=0.621 g=0.890
# 2/2 [==============================] - 0s 103ms/step
# Epoch>1, Batch319/390, d1=0.804, d2=0.669 g=0.869
# 2/2 [==============================] - 0s 103ms/step
# Epoch>1, Batch320/390, d1=0.828, d2=0.674 g=0.871
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch321/390, d1=0.820, d2=0.671 g=0.832
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch322/390, d1=0.843, d2=0.678 g=0.865
# 2/2 [==============================] - 0s 114ms/step
# Epoch>1, Batch323/390, d1=0.778, d2=0.661 g=0.877
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch324/390, d1=0.842, d2=0.627 g=0.940
# 2/2 [==============================] - 0s 108ms/step
# Epoch>1, Batch325/390, d1=0.815, d2=0.584 g=0.916
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch326/390, d1=0.743, d2=0.557 g=1.002
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch327/390, d1=0.749, d2=0.556 g=1.032
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch328/390, d1=0.697, d2=0.499 g=1.089
# 2/2 [==============================] - 0s 106ms/step
# Epoch>1, Batch329/390, d1=0.703, d2=0.472 g=1.125
# 2/2 [==============================] - 0s 102ms/step
# Epoch>1, Batch330/390, d1=0.708, d2=0.480 g=1.115
# 2/2 [==============================] - 0s 120ms/step
# Epoch>1, Batch331/390, d1=0.643, d2=0.499 g=1.033
# 2/2 [==============================] - 0s 108ms/step
# Epoch>1, Batch332/390, d1=0.691, d2=0.517 g=0.958
# 2/2 [==============================] - 0s 119ms/step
# Epoch>1, Batch333/390, d1=0.663, d2=0.596 g=0.914
# 2/2 [==============================] - 0s 139ms/step
# Epoch>1, Batch334/390, d1=0.640, d2=0.614 g=0.859
# 2/2 [==============================] - 0s 131ms/step
# Epoch>1, Batch335/390, d1=0.654, d2=0.685 g=0.820
# 2/2 [==============================] - 0s 121ms/step
# Epoch>1, Batch336/390, d1=0.608, d2=0.696 g=0.766
# 2/2 [==============================] - 0s 126ms/step
# Epoch>1, Batch337/390, d1=0.625, d2=0.709 g=0.775
# 2/2 [==============================] - 0s 115ms/step
# Epoch>1, Batch338/390, d1=0.664, d2=0.749 g=0.749
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch339/390, d1=0.698, d2=0.740 g=0.701
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch340/390, d1=0.692, d2=0.748 g=0.734
# 2/2 [==============================] - 0s 125ms/step
# Epoch>1, Batch341/390, d1=0.652, d2=0.725 g=0.735
# 2/2 [==============================] - 0s 112ms/step
# Epoch>1, Batch342/390, d1=0.733, d2=0.745 g=0.718
# 2/2 [==============================] - 0s 108ms/step
# Epoch>1, Batch343/390, d1=0.706, d2=0.734 g=0.769
# 2/2 [==============================] - 0s 130ms/step
# Epoch>1, Batch344/390, d1=0.692, d2=0.685 g=0.772
# 2/2 [==============================] - 0s 127ms/step
# Epoch>1, Batch345/390, d1=0.722, d2=0.717 g=0.789
# 2/2 [==============================] - 0s 114ms/step
# Epoch>1, Batch346/390, d1=0.783, d2=0.681 g=0.802
# 2/2 [==============================] - 0s 116ms/step
# Epoch>1, Batch347/390, d1=0.737, d2=0.654 g=0.832
# 2/2 [==============================] - 0s 115ms/step
# Epoch>1, Batch348/390, d1=0.732, d2=0.638 g=0.886
# 2/2 [==============================] - 0s 108ms/step
# Epoch>1, Batch349/390, d1=0.762, d2=0.625 g=0.893
# 2/2 [==============================] - 0s 117ms/step
# Epoch>1, Batch350/390, d1=0.712, d2=0.561 g=0.925
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch351/390, d1=0.756, d2=0.561 g=0.926
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch352/390, d1=0.683, d2=0.552 g=0.941
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch353/390, d1=0.682, d2=0.583 g=0.928
# 2/2 [==============================] - 0s 111ms/step
# Epoch>1, Batch354/390, d1=0.637, d2=0.553 g=0.921
# 2/2 [==============================] - 0s 113ms/step
# Epoch>1, Batch355/390, d1=0.661, d2=0.616 g=0.890
# 2/2 [==============================] - 0s 121ms/step
# Epoch>1, Batch356/390, d1=0.693, d2=0.599 g=0.886
# 2/2 [==============================] - 0s 122ms/step
# Epoch>1, Batch357/390, d1=0.638, d2=0.618 g=0.855
# 2/2 [==============================] - 0s 106ms/step
# Epoch>1, Batch358/390, d1=0.634, d2=0.641 g=0.863
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch359/390, d1=0.664, d2=0.587 g=0.904
# 2/2 [==============================] - 0s 123ms/step
# Epoch>1, Batch360/390, d1=0.659, d2=0.591 g=0.929
# 2/2 [==============================] - 0s 111ms/step
# Epoch>1, Batch361/390, d1=0.722, d2=0.572 g=0.932
# 2/2 [==============================] - 0s 113ms/step
# Epoch>1, Batch362/390, d1=0.625, d2=0.616 g=0.929
# 2/2 [==============================] - 0s 119ms/step
# Epoch>1, Batch363/390, d1=0.692, d2=0.610 g=0.834
# 2/2 [==============================] - 0s 113ms/step
# Epoch>1, Batch364/390, d1=0.638, d2=0.651 g=0.874
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch365/390, d1=0.668, d2=0.687 g=0.775
# 2/2 [==============================] - 0s 108ms/step
# Epoch>1, Batch366/390, d1=0.679, d2=0.716 g=0.713
# 2/2 [==============================] - 0s 107ms/step
# Epoch>1, Batch367/390, d1=0.702, d2=0.758 g=0.712
# 2/2 [==============================] - 0s 107ms/step
# Epoch>1, Batch368/390, d1=0.677, d2=0.725 g=0.749
# 2/2 [==============================] - 0s 112ms/step
# Epoch>1, Batch369/390, d1=0.585, d2=0.706 g=0.809
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch370/390, d1=0.615, d2=0.597 g=0.870
# 2/2 [==============================] - 0s 108ms/step
# Epoch>1, Batch371/390, d1=0.626, d2=0.562 g=0.928
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch372/390, d1=0.620, d2=0.533 g=0.973
# 2/2 [==============================] - 0s 110ms/step
# Epoch>1, Batch373/390, d1=0.627, d2=0.518 g=0.986
# 2/2 [==============================] - 0s 111ms/step
# Epoch>1, Batch374/390, d1=0.607, d2=0.546 g=0.949
# 2/2 [==============================] - 0s 108ms/step
# Epoch>1, Batch375/390, d1=0.606, d2=0.564 g=0.922
# 2/2 [==============================] - 0s 115ms/step
# Epoch>1, Batch376/390, d1=0.627, d2=0.576 g=0.917
# 2/2 [==============================] - 0s 121ms/step
# Epoch>1, Batch377/390, d1=0.581, d2=0.634 g=0.875
# 2/2 [==============================] - 0s 117ms/step
# Epoch>1, Batch378/390, d1=0.554, d2=0.631 g=0.859
# 2/2 [==============================] - 0s 116ms/step
# Epoch>1, Batch379/390, d1=0.553, d2=0.610 g=0.874
# 2/2 [==============================] - 0s 108ms/step
# Epoch>1, Batch380/390, d1=0.614, d2=0.588 g=0.898
# 2/2 [==============================] - 0s 113ms/step
# Epoch>1, Batch381/390, d1=0.586, d2=0.559 g=0.931
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch382/390, d1=0.631, d2=0.579 g=1.000
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch383/390, d1=0.637, d2=0.556 g=0.995
# 2/2 [==============================] - 0s 108ms/step
# Epoch>1, Batch384/390, d1=0.596, d2=0.552 g=1.033
# 2/2 [==============================] - 0s 108ms/step
# Epoch>1, Batch385/390, d1=0.572, d2=0.503 g=1.064
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch386/390, d1=0.625, d2=0.532 g=1.038
# 2/2 [==============================] - 0s 116ms/step
# Epoch>1, Batch387/390, d1=0.657, d2=0.580 g=0.923
# 2/2 [==============================] - 0s 133ms/step
# Epoch>1, Batch388/390, d1=0.705, d2=0.659 g=0.809
# 2/2 [==============================] - 0s 109ms/step
# Epoch>1, Batch389/390, d1=0.592, d2=0.720 g=0.757
# 2/2 [==============================] - 0s 111ms/step
# Epoch>1, Batch390/390, d1=0.760, d2=0.732 g=0.698
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# C:\Users\Eren\anaconda3\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# # 12. Visualization, Testing and Some Other Stuff

# %%
# Now, let us load the generator model and generate images
# Lod the trained model and generate a few images
from numpy import asarray
from numpy.random import randn
from numpy.random import randint
from keras.models import load_model
import numpy as np
# 

#Note: CIFAR10 classes are: airplane, automobile, bird, cat, deer, dog, frog, horse,
# ship, truck

# load model
model = g_model

# generate multiple images

latent_points, labels = generate_latent_points(100, 100)
# specify labels - generate 10 sets of labels each gping from 0 to 9
labels = asarray([x for _ in range(10) for x in range(10)])
# generate images
X  = model.predict([latent_points, labels])
# scale from [-1,1] to [0,1]
X = (X + 1) / 2.0
X = (X*255).astype(np.uint8)
# plot the result (10 sets of images, all images in a column should be of same class in the plot)
# Plot generated images 
def show_plot(examples, n):
	for i in range(n * n):
		plt.subplot(n, n, 1 + i)
		plt.axis('off')
		plt.imshow(examples[i, :, :, :])
	plt.show()
    
show_plot(X, 10)
# Out:
# 4/4 [==============================] - 1s 77ms/step
